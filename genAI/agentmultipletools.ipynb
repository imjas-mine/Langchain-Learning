# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["TAVILY_API_KEY"]=os.getenv("TAVILY_API_KEY")

from langchain_groq import ChatGroq

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

model=ChatGroq(model_name="qwen/qwen3-32b")

# %%
from langchain_tavily import TavilySearch

tavily_search_tool = TavilySearch(
    max_results=5,
    topic="general",
)

# %%
from langchain.tools import tool
@tool("calculator", description="Performs arithmetic calculations. Use this for any math problems.")
def calc(expression: str) -> str:
    """Evaluate mathematical expressions."""
    return str(eval(expression))

# %%
from langchain.agents import create_agent

agent=create_agent(
    model=model,
    tools=[tavily_search_tool, calc],
    
)

# %%
user_input="What is the latest news about AI for google and then calculate 2+2"

for step in agent.stream(
    {"messages":user_input},
    stream_mode="values"
):
   step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# What is the latest news about AI for google and then calculate 2+2
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search (6q01z00s6)
#  Call ID: 6q01z00s6
#   Args:
#     query: latest AI news Google
#     search_depth: advanced
#     time_range: day
#     topic: news
#   calculator (vrqbkpege)
#  Call ID: vrqbkpege
#   Args:
#     expression: 2+2
# ================================= Tool Message =================================
# Name: calculator
#
# 4
# ================================== Ai Message ==================================
#
# Here's the latest news about Google's AI developments and the calculation result:
#
# **Google's AI Updates in Gmail:**
# 1. **AI Inbox Feature**: Google is rolling out an AI-powered Gmail inbox that creates personalized to-do lists and task prioritization based on email content. This feature uses Gemini AI models to analyze emails and suggest actions like replying to messages, rescheduling appointments, or making payments.
# 2. **Enhanced AI Tools**: New Gemini-powered features now available to all Gmail users include:
#    - "Help Me Write" for personalized email drafting
#    - AI Overviews for email threads (provides TL;DR summaries)
#    - Natural language search capabilities (e.g., "What did I miss from the finance team last week?")
#
# **Calculation Result:**
# 2 + 2 = 4
#
# These updates are currently being tested in the US with plans for global expansion. The AI features prioritize user workflow efficiency while maintaining privacy controls.
